# %%
import matplotlib.pyplot as plt

# %%
ex_vals = [1600,600,100,410,250]
exp_lable = ['Home Rent','Food','Phone/internet sill','Car','other utilities']

# %%
plt.axis("equal")
plt.pie(ex_vals,labels=exp_lable,radius=1.5,shadow=True,explode=[0,0.1,0.1,0,0],startangle=90)
plt.show()
