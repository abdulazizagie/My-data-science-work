# %%
import pandas as pd

df  = pd.read_csv("car_price_data1 (1).csv",parse_dates=['EngineV'])
df
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_3536\1284522539.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df  = pd.read_csv("car_price_data1 (1).csv",parse_dates=['EngineV'])
#               Brand     Price       Body  Mileage EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277       2      Petrol
# 1     Mercedes-Benz    7900.0        van      427     2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358       5         Gas
# 3              Audi   23000.0  crossover      240     4.2      Petrol
# 4            Toyota   18300.0  crossover      120       2      Petrol
# ...             ...       ...        ...      ...     ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9       3      Diesel
# 4341            BMW    6500.0      sedan        1     3.5      Petrol
# 4342            BMW    8000.0      sedan      194       2      Petrol
# 4343         Toyota   14200.0      sedan       31     NaN      Petrol
# 4344     Volkswagen   13500.0        van      124       2      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
new_df = df.fillna({
    'EngineV':0,
})
new_df
# Out:
#               Brand     Price       Body  Mileage EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277       2      Petrol
# 1     Mercedes-Benz    7900.0        van      427     2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358       5         Gas
# 3              Audi   23000.0  crossover      240     4.2      Petrol
# 4            Toyota   18300.0  crossover      120       2      Petrol
# ...             ...       ...        ...      ...     ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9       3      Diesel
# 4341            BMW    6500.0      sedan        1     3.5      Petrol
# 4342            BMW    8000.0      sedan      194       2      Petrol
# 4343         Toyota   14200.0      sedan       31       0      Petrol
# 4344     Volkswagen   13500.0        van      124       2      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
new_df = df.fillna(method='ffill',limit=1)
new_df
# Out:
#               Brand     Price       Body  Mileage EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277       2      Petrol
# 1     Mercedes-Benz    7900.0        van      427     2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358       5         Gas
# 3              Audi   23000.0  crossover      240     4.2      Petrol
# 4            Toyota   18300.0  crossover      120       2      Petrol
# ...             ...       ...        ...      ...     ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9       3      Diesel
# 4341            BMW    6500.0      sedan        1     3.5      Petrol
# 4342            BMW    8000.0      sedan      194       2      Petrol
# 4343         Toyota   14200.0      sedan       31       2      Petrol
# 4344     Volkswagen   13500.0        van      124       2      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
new_df = df.interpolate()
new_df
# Out:
#               Brand     Price       Body  Mileage EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277       2      Petrol
# 1     Mercedes-Benz    7900.0        van      427     2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358       5         Gas
# 3              Audi   23000.0  crossover      240     4.2      Petrol
# 4            Toyota   18300.0  crossover      120       2      Petrol
# ...             ...       ...        ...      ...     ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9       3      Diesel
# 4341            BMW    6500.0      sedan        1     3.5      Petrol
# 4342            BMW    8000.0      sedan      194       2      Petrol
# 4343         Toyota   14200.0      sedan       31     NaN      Petrol
# 4344     Volkswagen   13500.0        van      124       2      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %%
new_df = df.dropna()
new_df
# Out:
#               Brand     Price       Body  Mileage EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277       2      Petrol
# 1     Mercedes-Benz    7900.0        van      427     2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358       5         Gas
# 3              Audi   23000.0  crossover      240     4.2      Petrol
# 4            Toyota   18300.0  crossover      120       2      Petrol
# ...             ...       ...        ...      ...     ...         ...
# 4339         Toyota   17900.0      sedan       35     1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9       3      Diesel
# 4341            BMW    6500.0      sedan        1     3.5      Petrol
# 4342            BMW    8000.0      sedan      194       2      Petrol
# 4344     Volkswagen   13500.0        van      124       2      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4339          yes  2014            Corolla
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4344          yes  2013  T5 (Transporter)
#
# [4025 rows x 9 columns]

# %%
df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df
# Out:
#             day  temperature  windspeed event
# 2017-01-01  NaN          NaN        NaN   NaN
# 2017-01-02  NaN          NaN        NaN   NaN
# 2017-01-03  NaN          NaN        NaN   NaN
# 2017-01-04  NaN          NaN        NaN   NaN
# 2017-01-05  NaN          NaN        NaN   NaN
# 2017-01-06  NaN          NaN        NaN   NaN
# 2017-01-07  NaN          NaN        NaN   NaN
# 2017-01-08  NaN          NaN        NaN   NaN
# 2017-01-09  NaN          NaN        NaN   NaN
# 2017-01-10  NaN          NaN        NaN   NaN
# 2017-01-11  NaN          NaN        NaN   NaN
