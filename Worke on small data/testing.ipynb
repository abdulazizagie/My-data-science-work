# %% [markdown]
# ### import lobrary in all data science work

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### import the datafram file

# %%
car = pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
car.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
car.shape
# Out:
# (4340, 8)

# %%
car.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
car.describe(include='all')
# Out:
#                           name         year  selling_price      km_driven  \
# count                     4340  4340.000000   4.340000e+03    4340.000000
# unique                    1491          NaN            NaN            NaN
# top     Maruti Swift Dzire VDI          NaN            NaN            NaN
# freq                        69          NaN            NaN            NaN
# mean                       NaN  2013.090783   5.041273e+05   66215.777419
# std                        NaN     4.215344   5.785487e+05   46644.102194
# min                        NaN  1992.000000   2.000000e+04       1.000000
# 25%                        NaN  2011.000000   2.087498e+05   35000.000000
# 50%                        NaN  2014.000000   3.500000e+05   60000.000000
# 75%                        NaN  2016.000000   6.000000e+05   90000.000000
# max                        NaN  2020.000000   8.900000e+06  806599.000000
#
#           fuel seller_type transmission        owner
# ...

# %%
car.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
print(car.isnull().sum())
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
car.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'selling_price'}>],
#        [<AxesSubplot:title={'center':'km_driven'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.pairplot(car)

# %%
car.count()
# Out:
# name             4340
# year             4340
# selling_price    4340
# km_driven        4340
# fuel             4340
# seller_type      4340
# transmission     4340
# owner            4340
# dtype: int64

# %%
car.shape
# Out:
# (4340, 8)

# %%
duplicated_car_plot = car[car.duplicated()]
duplicated_car_plot.shape
# Out:
# (763, 8)

# %%
car = car.drop_duplicates()
car.shape
# Out:
# (3577, 8)

# %%
car = car.dropna()
car.count()
# Out:
# name             3577
# year             3577
# selling_price    3577
# km_driven        3577
# fuel             3577
# seller_type      3577
# transmission     3577
# owner            3577
# dtype: int64

# %%
car.name.value_counts().nlargest(40).plot(kind='bar',figsize=(5,5))
plt.title("owner")
plt.xlabel("Owner")
plt.ylabel("performans")
# Out:
# Text(0, 0.5, 'performans')

# %%
plt.figure(figsize=(20 ,10))
c =  car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                   year  selling_price  km_driven
# year           1.00000       0.424260  -0.417490
# selling_price  0.42426       1.000000  -0.187359
# km_driven     -0.41749      -0.187359   1.000000
