# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)

# %%
car = pd.read_csv("car_price_data1 (1).csv")
print(car.head())
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %%
car.dtypes
# Out:
# Brand            object
# Price           float64
# Body             object
# Mileage           int64
# EngineV         float64
# Engine Type      object
# Registration     object
# Year              int64
# Model            object
# dtype: object

# %%
car.columns
# Out:
# Index(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'Model'],
#       dtype='object')

# %% [markdown]
# ## Analytical Summary of the dataset

# %%
car.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# ...

# %%
car.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot: title={'center': 'Price'}>,
#         <AxesSubplot: title={'center': 'Mileage'}>],
#        [<AxesSubplot: title={'center': 'EngineV'}>,
#         <AxesSubplot: title={'center': 'Year'}>]], dtype=object)

# %% [markdown]
# ## Relationship between categorical and continues variable

# %%
sns.boxplot(x = "Body" , y = "EngineV",data= car)
# Out:
# <AxesSubplot: xlabel='Body', ylabel='EngineV'>

# %%
sns.pairplot(car)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\abdul\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\abdul\AppData\Local\Temp\ipykernel_20532\2019724112.py", line 1, in <module>
#     sns.pairplot(car)
#   File "c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py", line 2144, in pairplot
#     grid.map_diag(histplot, **diag_kws)
#   File "c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py", line 1507, in map_diag
#     func(x=vector, **plot_kwargs)
#   File "c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py", line 1418, in histplot
#     color = _default_color(method, hue, color, kwargs)
# ...

# %% [markdown]
# ## Dropnirrelevant columns

# %%
car = car.drop(['EngineV','Engine Type'],axis=1) 
# car.columns

# %%
car.head()
# Out:
#            Brand    Price       Body  Mileage Registration  Year         Model
# 0            BMW   4200.0      sedan      277          yes  1991           320
# 1  Mercedes-Benz   7900.0        van      427          yes  1999  Sprinter 212
# 2  Mercedes-Benz  13300.0      sedan      358          yes  2003         S 500
# 3           Audi  23000.0  crossover      240          yes  2007            Q7
# 4         Toyota  18300.0  crossover      120          yes  2011         Rav 4

# %%
car = car.rename(columns={"Brand":'Br'})
car.head()
# Out:
#               Br    Price       Body  Mileage Registration  Year         Model
# 0            BMW   4200.0      sedan      277          yes  1991           320
# 1  Mercedes-Benz   7900.0        van      427          yes  1999  Sprinter 212
# 2  Mercedes-Benz  13300.0      sedan      358          yes  2003         S 500
# 3           Audi  23000.0  crossover      240          yes  2007            Q7
# 4         Toyota  18300.0  crossover      120          yes  2011         Rav 4

# %% [markdown]
# ### total of row and columns

# %%
car.shape
# Out:
# (4345, 7)

# %% [markdown]
# ### Row cantaining duplict data

# %%
duplicte_row_car = car[car.duplicated()]
print("Number of duplict row : ",duplicte_row_car.shape)
# Out:
# Number of duplict row :  (88, 7)

# %% [markdown]
# ### Count the row before removing the data

# %%
car.count()
# Out:
# Br              4345
# Price           4173
# Body            4345
# Mileage         4345
# Registration    4345
# Year            4345
# Model           4345
# dtype: int64

# %%
car.shape
# Out:
# (4345, 7)

# %%
car = car.drop_duplicates()
car.count()
# Out:
# Br              4257
# Price           4111
# Body            4257
# Mileage         4257
# Registration    4257
# Year            4257
# Model           4257
# dtype: int64

# %% [markdown]
# ### find the null value

# %%
print(car.isnull().sum())
# Out:
# Br                0
# Price           146
# Body              0
# Mileage           0
# Registration      0
# Year              0
# Model             0
# dtype: int64

# %%
car =  car.dropna()
car.count()
# Out:
# Br              4111
# Price           4111
# Body            4111
# Mileage         4111
# Registration    4111
# Year            4111
# Model           4111
# dtype: int64

# %%
print(car.isnull().sum())
# Out:
# Br              0
# Price           0
# Body            0
# Mileage         0
# Registration    0
# Year            0
# Model           0
# dtype: int64

# %% [markdown]
# ### Finding  the outliers

# %%
sns.boxplot(x=car['Price'])
# Out:
# <AxesSubplot: xlabel='Price'>

# %%
sns.boxplot(x = car['Price'])
# Out:
# <AxesSubplot: xlabel='Price'>

# %% [markdown]
# ### plotting a Hastogam for number of car per brand

# %%
car.Price.value_counts().nlargest(40).plot(kind='bar',figsize=(20,5))
plt.xlabel("Count of Tips Received")
# plt.ylabel("Day of Week", labelpad=14)
# plt.title("Count of Tips by Day of Week", y=1.02);
# Out:
# Text(0.5, 0, 'Count of Tips Received')

# %% [markdown]
# ### Finding  the  relation brtween thr variable

# %%
plt.figure(figsize=(20 ,10))
c =  car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_20532\1891695643.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c =  car.corr()
#             Price   Mileage      Year
# Price    1.000000 -0.454419  0.480904
# Mileage -0.454419  1.000000 -0.651307
# Year     0.480904 -0.651307  1.000000
